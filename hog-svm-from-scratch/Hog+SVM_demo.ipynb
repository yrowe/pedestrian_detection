# %% [markdown]
# # Hog+SVM(demo version)
# this notebook is a simple implement of pedestrian detection using Hog+SVM provided by opencv.

# %% [markdown]
# ## environment
# python 3.6
#
# library:
# - opencv3 for python3
# - imutils
# - numpy
# - matplotlib
# - imutils

# %%
import cv2
import matplotlib.pyplot as plt
import imutils
import numpy as np
from imutils.object_detection import non_max_suppression
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9e84dab3f3d3> in <module>()
# ----> 1 import cv2
#       2 import matplotlib.pyplot as plt
#       3 import imutils
#       4 import numpy as np
#       5 from imutils.object_detection import non_max_suppression
#
# ModuleNotFoundError: No module named 'cv2'

# %%
## a simple way to show the image
from PIL import Image
ii = Image.open("./1.jpg")
ii
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7F0FB2331E48>

# %% [markdown]
# ## read image

# %%
img = cv2.imread("../46_CUHK Occlusion Dataset/raw_img/set00-occ/1.jpg")

# %%
#use opencv to show the image
#cv2.imshow("Image", img)
#cv2.waitKey (0)

# %%
plt_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(plt_img)
plt.axis("off")
plt.show()

# %%
print(img.dtype)
print(img.shape)
# Out:
# uint8
# (480, 640, 3)

# %%
# initialize the HOG descriptor/person detector
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())

# %%
img = imutils.resize(img, width=min(400, img.shape[1]))

# %%
img.shape
# Out:
# (300, 400, 3)

# %%
(rects,weights) = hog.detectMultiScale(img,winStride=(4,4),padding=(8,8),scale=1.05)

# %%
for (x,y,w,h) in rects:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)

# %%
plt_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(plt_img)
plt.axis("off")
plt.show()
